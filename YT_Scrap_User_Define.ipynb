# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import StaleElementReferenceException
import time

# %%
def scrape_youtube_comments(video_url, max_attempts=10, scroll_pause_time=2, scroll_increment=500):
    """
    Scrape comments from a YouTube video.
    
    Args:
        video_url: URL of the YouTube video
        max_attempts: Maximum number of scroll attempts with no new content
        scroll_pause_time: Time to pause between scrolls (seconds)
        scroll_increment: Pixels to scroll each time
        
    Returns:
        List of unique comments
    """
    # Set up Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--disable-notifications")
    chrome_options.add_argument("--disable-infobars")
    
    # Initialize the driver
    driver = webdriver.Chrome(options=chrome_options)
    driver.maximize_window()
    
    try:
        # Load the video
        driver.get(video_url)
        time.sleep(3)
        
        # Initialize variables
        all_comments = []
        seen_comments = set()
        attempts = 0
        
        # Initial scroll to trigger comments section
        driver.execute_script("window.scrollTo(0, 700)")
        time.sleep(3)
        
        last_height = driver.execute_script("return document.documentElement.scrollHeight")
        
        # Main scrolling loop
        while attempts < max_attempts:
            # Scroll down gradually
            current_position = driver.execute_script("return window.pageYOffset")
            target_position = current_position + scroll_increment
            driver.execute_script(f"window.scrollTo(0, {target_position})")
            time.sleep(scroll_pause_time)
            
            # Extract comments with error handling
            try:
                comments = driver.find_elements(By.CLASS_NAME, "yt-core-attributed-string.yt-core-attributed-string--white-space-pre-wrap")
                
                # Process new comments
                for comment in comments:
                    try:
                        comment_text = comment.text
                        if comment_text and comment_text not in seen_comments:
                            seen_comments.add(comment_text)
                            all_comments.append(comment_text)
                            print(f"New comment added: {comment_text[:50]}..." if len(comment_text) > 50 else f"New comment added: {comment_text}")
                    except StaleElementReferenceException:
                        # Handle stale elements (page content changed)
                        continue
            except Exception as e:
                print(f"Error extracting comments: {str(e)}")
            
            # Check if we've reached bottom
            new_height = driver.execute_script("return document.documentElement.scrollHeight")
            if new_height == last_height:
                attempts += 1
                print(f"No new content detected ({attempts}/{max_attempts})")
            else:
                attempts = 0  # Reset counter if new content was loaded
                
            last_height = new_height
            
        print(f"\nFinished scrolling! Total unique comments collected: {len(all_comments)}")
        return all_comments
        
    finally:
        # Ensure browser is closed even if an exception occurs
        driver.quit()

# %% [markdown]
# # Text Use

# %%
# Example usage
if __name__ == "__main__":
    video_url = "https://www.youtube.com/watch?v=ZTiUoKSAHaU"
    
    # Store the returned comments in a variable
    collected_comments = scrape_youtube_comments(video_url)
    
    # Now you can access the comments using the 'collected_comments' variable
    
    # Print all collected comments
    print("\nAll Comments:")
    for i, comment in enumerate(collected_comments, 1):
        print(f"{i}. {comment}")
    
    # Save to a file if desired
    def save_comments_to_file(comments, filename="youtube_comments.txt"):
        with open(filename, "w", encoding="utf-8") as f:
            for i, comment in enumerate(comments, 1):
                f.write(f"Comment #{i}:\n{comment}\n\n")
        print(f"Comments saved to {filename}")
    
    # Save the comments to a file
    save_comments_to_file(collected_comments)
# Out:
# New comment added: You saw how I condensed 1000+ hours of System Desi...
# New comment added: While many are charging ₹1.6 lakhs for a similar r...
# New comment added: Notes -
#
# 1st Month - Programming Language + Compl...
# New comment added: 1:40 -1st Month - Programming Language + Complexit...
# New comment added: Big request! Please make a roadmap for engineering...
# New comment added: trust me if you have never been topper giy you can...
# New comment added: Great content
# New comment added: Thanks For this
# New comment added: Well structured video.
# New comment added: Thank you mam
# New comment added: Now i have to crack Google just to See you daily.
# New comment added: Thank you
# New comment added: Thanks for providing such a valuable session from ...
# New comment added: But i believe your past experience got you into bi...
# New comment added: Di can you guide on job hunt and how to reach recr...
# New comment added: Great
# New comment added: Useful content, By the way you're looking gorgeous...
# New comment added: yea this is gonna blow up
# New comment added: What should I do first Dsa or Web dev being a 3rd ...
# New comment added: Thank you so much ma'am for this...........
# New comment added: For LeetCode, would you suggest C++ or Python?
# New comment added: Office Property at ₹99Lacs* in Aundh
# New comment added: 1st Robotic Car Parking System | 150+ unique offic...
# New comment added: The Anthem
# No new content detected (1/10)
# No new content detected (1/10)
# No new content detected (2/10)
# New comment added: Thank you
# New comment added: If possible, please create a PDF in which the main...
# New comment added: keep this Information in mind ( She is from "Indir...
# New comment added: This is alot to cover in 6 months for a beginner. ...
# New comment added: What would change in the roadmap if I am targettti...
# New comment added: Thank you so much for the video. It helps a lot by...
# New comment added: hi can you please elaborate on making projects? ev...
# New comment added: I almost always clear coding interview rounds of m...
# New comment added: Hey, I just want to ask one simple question - If I...
# New comment added: For a backend developer can I go ahead and host my...
# New comment added: Where should I learn about AI and how to start the...
# New comment added: Maam can u pls provide resources also ?
# New comment added: Mam in DSA rounds we have to code solutions from b...
# New comment added: Please can you share me road map for about 10 year...
# New comment added: If you are dsa then I  dsa
# New comment added: I can't understand one thing that in 1st month you...
# New comment added: Start a DSA series in your channel if it's possibl...
# New comment added: kindly add resources
# New comment added: Ma'am in which tech we make a project.  Mern or Re...
# New comment added: I am graduating 2023, is it still possible to land...
# No new content detected (1/10)
# No new content detected (1/10)
# No new content detected (2/10)
# New comment added: Nice
# New comment added: I am from non tech and i am from Pakistan Can i jo...
# New comment added: course mat bachna plz aaj se 6 saal baad
# New comment added: Jai Mata Di!
# You are already so beautiful that no...
# New comment added: First Step for any interview: Get your resume SHOR...
# New comment added: I am graduate in 2024, working at small company wo...
# New comment added: I a working professional my plan for cracking Maan...
# New comment added: Is there a roadmap to win your heart ? <3
# New comment added: Does experience from service based company counts ...
# New comment added: I m learning python prog lang now i want to learn ...
# New comment added: 0:40 it wasn't easy in 2024
# New comment added: From X
# New comment added: I have 2 years career break as a fresher..Is this ...
# New comment added: So baby you are saying job in big companies is onl...
# New comment added: mam ek pdf provide kara do ?
# New comment added: Guys, remember the truth is always hidden in the m...
# New comment added: Sounds good..
# Doesn't work!
# New comment added: Free things are not worthy.
# New comment added: Lint code Thanks a lot
# New comment added: Coding Interview Solutions
# New comment added: NeetCode
# New comment added: Playlist
# New comment added: View full playlist
# New comment added: Coding Interviews
# New comment added: Ashish Pratap Singh
# New comment added: Course
# New comment added: View full course
# No new content detected (1/10)
# No new content detected (2/10)
# New comment added: 6 months no , 1.5 year yes
# New comment added: Plz make system design proper roadmap
# New comment added: I am a first year btech graduate....hoping To get ...
# New comment added: broooo..................
# New comment added: Love you Anu baby
# New comment added: Will it help for tier 3 college student  also
# New comment added: How do you think a guy can start from scratch and ...
# New comment added: You marry me that is enough
# New comment added: Did what about MERN stack? I have completed lectur...
# New comment added: Dsa is not my cup of tea. what should I do
# New comment added: Its happening that i know the logic, but failing t...
# No new content detected (1/10)
# No new content detected (2/10)
# No new content detected (3/10)
# No new content detected (1/10)
# No new content detected (2/10)
# No new content detected (3/10)
# No new content detected (4/10)
# No new content detected (1/10)
# No new content detected (2/10)
# No new content detected (3/10)
# No new content detected (4/10)
# No new content detected (5/10)
# No new content detected (6/10)
# No new content detected (7/10)
# No new content detected (8/10)
# No new content detected (9/10)
# No new content detected (10/10)
#
# Finished scrolling! Total unique comments collected: 82
#
# All Comments:
# 1. You saw how I condensed 1000+ hours of System Design. Now, I've mapped out the entire 6-month journey to help YOU land a job in Big Tech, using everything I've learned.
# 2. While many are charging ₹1.6 lakhs for a similar roadmap, claiming to offer placement assistance for MAANG companies, you're generously providing crisp and on point  valuable information,  for free. Truly hats off to your dedication and incredible work — it's deeply appreciated!
# 3. Notes -
#
# 1st Month - Programming Language + Complexity/Basic DSA (Easy problems on LeetCode)
# 2nd Month - Intermediate DSA (Med problems on Leet code) + AI fundamentals
# 3rd Month - Advanced DSA + Brainstorming Project Ideas + System Design Fundamentals
# 4th Month - More Advanced on DSA and practice more + Deep Dive in System Design + Build Projects
# 5th Month - Mock Interviews + Practice company specific questions + Start Job Search + Complete & Deploy Projects
# 6th Month - Final preparation + Refine your skills
#
# (Lintcode for LeetCode premium questions)
# 4. 1:40 -1st Month - Programming Language + Complexity/Basic DSA (Easy problems on LeetCode)
#
# 3:08 -2nd Month - Intermediate DSA (Med problems on LeetCode) + AI fundamentals
#
#  -3rd Month - Advanced DSA + Brainstorming Project Ideas + System Design Fundamentals
#
#  -4th Month - More Advanced on DSA and practice more + Deep Dive in System Design + Build Projects
#
#  -5th Month - Mock Interviews + Practice company-specific questions + Start Job Search + Complete & Deploy Projects
#
#  -6th Month - Final preparation + Refine your skills
#
# As usual good content Anu.
# 5. Big request! Please make a roadmap for engineering graduates who never studied coding. Most roadmaps are for students in college (1st -4 th year) and span 6-8 months due to their busy schedules. But what about us, the passed-out students facing immense pressure? The good thing—we have 24 hours free (not working), so with the right 3 month plan, we can turn things around. We need a frontend roadmap with one strong project to get a job. Also, not hardcore DSA, just some important questions companies actually ask.
# Please let me know if you’ll make this video, and if yes, when?
# 6. trust me if you have never been topper giy you can't do all these in a span of 6 months it's impossible it took me more than a year to learn all this still learning ...
# i think all this influencers are elites that why they think anyone can do such thing in such a short span if their  is any juniour out their stop listening influencers bullshit.... they are elite . you & i being an avg wathing them ain't gonna achieve anything like this ...
#
# pain of final year student please juniors gaand phaad mehanat maaro tabhi kuch honga vrna nii hota ye mam kaafi achhe and DTU se pass out hain to already kind of bahut brilliant hain ye ... mostly log n kar payenge itne time par main likh kar keh skta mujhe khudh striver sheet finish krne mein 9 month dedication ke sath krne par khatam huyi hain ....  its fucking hard ...
#
# ps : if you are someone from such a family who never had tech acces  during teens i was someone who didnt even no creation of directory (brutally honest) bas mehanat karo gaand phaad tabhi honga kuch vrna next berozgaar club ap bhi join kronge
# 7. Great content
# 8. Thanks For this
# 9. Well structured video.
# 10. Thank you mam
# 11. Now i have to crack Google just to See you daily.
# 12. Thank you
# 13. Thanks for providing such a valuable session from you relly help a lot for preparation Anu,Keep doing the great work
# 14. But i believe your past experience got you into big tech, were you asked system design concepts in twitter interview or was it pure DSA ?
# 15. Di can you guide on job hunt and how to reach recruiter , I am passing out from college in two months.
# 16. Great
# 17. Useful content, By the way you're looking gorgeous
# 18. yea this is gonna blow up
# 19. What should I do first Dsa or Web dev being a 3rd tier college student?
# 20. Thank you so much ma'am for this...........
# 21. For LeetCode, would you suggest C++ or Python?
# 22. Office Property at ₹99Lacs* in Aundh
# 23. 1st Robotic Car Parking System | 150+ unique office spaces | Centrally Located in Aundh
# 24. The Anthem
# 25. Thank you
# 26. If possible, please create a PDF in which the main topic is mentioned, followed by the subtopics
# 27. keep this Information in mind ( She is from "Indira Gandhi Delhi Technical University" which is in among the top colleges, and she have 9.3 CGPA in college )
# 28. This is alot to cover in 6 months for a beginner. People might try to do everything only to realize they haven't learnt anything
# So DSA + Giving contest atleast for me  for the next 6 months
# 29. What would change in the roadmap if I am targettting remote startups?
# 30. Thank you so much for the video. It helps a lot by planning month wise as you said. I want to learn Mern Stack. Will you please share the resources starting from HTML.
# 31. hi can you please elaborate on making projects? everyone keeps saying build projects.
# do we like use html css js and build frontend projects? or something else?
# 32. I almost always clear coding interview rounds of most companies (except google in which I mostly get border line average feedback and get rejected); but I mostly get rejected in system design rounds. Currently for google, HR is considering me for L5 (SSE) role in continuation with my last interview feedbacks even though it was mixed on avg (+ve, neutral, -ve respectively for 3 coding rounds), and subsequent rounds will be system design and then additonal coding round and then googliness round. Any suggestions on how to crack google level system design for L5 role (I have 9+ years of experience, currently working as senior software engineer in Coupang in singapore).
# 33. Hey, I just want to ask one simple question - If I follow this whole heartedly, will this work? I respect you and that's the only reason I'm commenting. Just want to know whether it is proven or not? Right now, I just need a hope, a genuine hope and suddenly your video dropped I was so happy so see it's title.
# 34. For a backend developer can I go ahead and host my project with out front-end. Will that be ok for a portfolio?
# 35. Where should I learn about AI and how to start the learning?
# 36. Maam can u pls provide resources also ?
# 37. Mam in DSA rounds we have to code solutions from brute better to optimal ?
# 38. Please can you share me road map for about 10 year experience
# 39. If you are dsa then I  dsa
# 40. I can't understand one thing that in 1st month you mentioned about all sorting algos in which merge sort which involves (DNC) also and in next month to learn recursion but doesn't it waste of time and energy
# 41. Start a DSA series in your channel if it's possible?
# 42. kindly add resources
# 43. Ma'am in which tech we make a project.  Mern or React+Springboot.
#
# Thanks for roadmap.
# 44. I am graduating 2023, is it still possible to land a decent company, please reply, i am blidinly following your system design roadmap! I am from non cs background
# 45. Nice
# 46. I am from non tech and i am from Pakistan Can i join big companies as I have no degree
#
# My this year goal is to learn
# Backend with Node JS as I learnt JavaScript
# DSA with C++
# Networking
# DBMS
# Operating systems
# System Designs
#
# And if anything missing tell me
#
# And Can you make video on how non tech students become software engineers by learning own and which roadmap to follow?
# 47. course mat bachna plz aaj se 6 saal baad
# 48. Jai Mata Di!
# You are already so beautiful that no matter what you wear, you look amazing! If you choose a kurti or saree, it just enhances your charm even more. I’m just saying, praising someone so gorgeous feels like honoring a divine creation! ️
# 49. First Step for any interview: Get your resume SHORTLISTED and this is not happening anywhere.
# 50. I am graduate in 2024, working at small company working on react and stuff java little bit, what can I do I get a into good MNC or company ASAP
# 51. I a working professional my plan for cracking Maang is to dedicate around 2 hr on DSA and 2 hours on MERN stack on weekends. Focus on system design, is there anything you want to suggest on this? I really appreciate any help you can provide. As of now, I go through topics on DSA for three days, and then do questions related to that topic for 3 days
# 52. Is there a roadmap to win your heart ? <3
# 53. Does experience from service based company counts in big PBCs ?
# 54. I m learning python prog lang now i want to learn dsa with python can you plz provide some resources
# 55. 0:40 it wasn't easy in 2024
# 56. From X
# 57. I have 2 years career break as a fresher..Is this road map applicable for me?
# 58. So baby you are saying job in big companies is only about DSA, Algorithm and AI knowledge
# 59. mam ek pdf provide kara do ?
# 60. Guys, remember the truth is always hidden in the mundane
# 61. Sounds good..
# Doesn't work!
# 62. Free things are not worthy.
# 63. Lint code Thanks a lot
# 64. Coding Interview Solutions
# 65. NeetCode
# 66. Playlist
# 67. View full playlist
# 68. Coding Interviews
# 69. Ashish Pratap Singh
# 70. Course
# 71. View full course
# 72. 6 months no , 1.5 year yes
# 73. Plz make system design proper roadmap
# 74. I am a first year btech graduate....hoping To get some hope
# 75. broooo..................
# 76. Love you Anu baby
# 77. Will it help for tier 3 college student  also
# 78. How do you think a guy can start from scratch and make good even projects on ml in a bunch of months of starting to learn it.
#
# I think ml needs a lot more time than that to make something worth showing on resume
# 79. You marry me that is enough
# 80. Did what about MERN stack? I have completed lectures on DSA and I've started leetcode since April first and my placement season is in the month of June, what should I do, should I learn mern stack? It was not mentioned in the video
# 81. Dsa is not my cup of tea. what should I do
# 82. Its happening that i know the logic, but failing to write the code at omce, how to tackle this?
# Comments saved to youtube_comments.csv

# %% [markdown]
# # CSV Use

# %%
def save_comments_to_csv(comments, filename="youtube_comments.csv"):
    """
    Save comments to a CSV file.
    
    Args:
        comments: List of comments to save
        filename: Name of the CSV file
    """
    with open(filename, "w", encoding="utf-8", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Comment Number", "Comment Text"])
        for i, comment in enumerate(comments, 1):
            writer.writerow([i, comment])
    print(f"Comments saved to {filename}")

# Example usage
if __name__ == "__main__":
    video_url = "https://www.youtube.com/watch?v=4A_kmjtsJ7c"
    
    # Scrape comments
    collected_comments = scrape_youtube_comments(video_url)
    
    # Print all collected comments
    print("\nAll Comments:")
    for i, comment in enumerate(collected_comments, 1):
        print(f"{i}. {comment}")
    
    # Save comments to CSV
    save_comments_to_csv(collected_comments)
